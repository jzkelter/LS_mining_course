# %% [markdown]
# # Introduction

# %% [markdown]
# ## What's the big deal

# %% [markdown]
# ### New sources and scales of text data
#
# * Generated by students as they work online
# * From the internet
# * From books, etc.
#
# ### New computer-based techniques for working with and analyzing this data
#
# * More powerful computers
# * New algorithms
# * New tools

# %% [markdown]
# ## The lay of the land

# %% [markdown]
# ### Educational data mining
#
# * Came out of intelligent tutoring literature
#
# ### Learning analytics
#
# * Driven by emergence of data generated by student online work
# * Often an mphasis on data visualization and relatively simple metrics.

# %% [markdown]
# ## A couple of examples

# %% [markdown]
# ### Word co-occurrence patterns

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Given a coded dataset, train a computer to code the same type of data.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Automatically discover codes

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## The approach

# %% [markdown]
# ### What I want you to learn

# %% [markdown]
# * Enough to know what is possible
#     * This means understanding the space of algorithms
# * Enough practical skills that you know how to find resources, and build more extensive knowledge in the areas that you care about
#     * This means understanding the space of tools
# * Generally I think the most useful things I can teach you are extremely practical skills.

# %% [markdown]
# ### A python-oriented toolset

# %% [markdown]
# * We'll be building python expertise a little at a time

# %% [markdown]
# ## Course Outline

# %% [markdown]
# ### 1. Getting started

# %% [markdown]
# * First steps with Python
# * First steps with text analysis
#     * Loading a corpus
#     * Simple explorations of word use
# * Installing and getting started with the toolset

# %% [markdown]
# ### 2. Counting words

# %% [markdown]
# * Frequency distributions
# * Representations of co-occurrence
# * Collocations and n-grams
# * More python

# %% [markdown]
# ### 3. Vector space methods

# %% [markdown]
# * Converting text to a vector
# * Various representations of vectors
# * Use of vector representations to measure text similarity
# * Distributed vector representations
# * Similarity measures more generally

# %% [markdown]
# ### 4. Normalizing Text

# %% [markdown]
# * Tokenizing
# * Stemming
# * Lemmatizing
# * Regular Expressions

# %% [markdown]
# ### 5. Supervised methods (classification)

# %% [markdown]
# * Methods
#     * Decision Trees
#     * Naive Bayes
#     * Support Vector Machines
#     * Neural Networks
# * Testing frameworks

# %% [markdown]
# ### 6. Interlude: Working with real data

# %% [markdown]
# * Assembling raw data
#     * From the web: web pages, twitter, etc.
#     * From PDFs

# %% [markdown]
# ### 7. Unsupervised methods

# %% [markdown]
# * Text Clustering
# * Topic Modeling

# %% [markdown]
# ### 8. Context-aware text processing

# %% [markdown]
# * Incoporating part-of-speech tagging.

# %% [markdown]
# ## Work that you'll do

# %% [markdown]
# * Weekly short workbook-based analysis tasks
# * 1 tool report
# * Assemble one corpus of your own
#     * Propose and do some analysis of it.
